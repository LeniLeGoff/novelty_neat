# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_map(files, title="", filename="", pos=0):
    fig1, ax1 = plt.subplots()
    plt.xlim(0,600)
    plt.ylim(0,600)
    if (not (type(files) is list)):
        files=[files]
    pointx=[]
    pointy=[]
    for rf in files:
        f=open(rf)
        for l in f.readlines():
            l=l.rstrip()
            lc=list(map(float, l.split(" ")))
            pointx.append(lc[0+pos])
            pointy.append(600-lc[1+pos])
        f.close()
    print("nb points: "+str(len(pointx))+" min=(%.2f, %.2f)"%(min(pointx),min(pointy))+" max=(%.2f,%.2f)"%(max(pointx),max(pointy)))
    ax1.plot(pointx,pointy,'.')
    ax1.set_title(title)
    if (filename):
        fig1.savefig(filename)

# %%
logs_dir = "/home/leni/sferes_log/"
import os

# %%
print("First run : 4000 gen and 400 init pop")
# Out:
# First run : 4000 gen and 400 init pop

# %%
print("CONTROL EXPERIMENT no novelty no neat")
first_run_dir = logs_dir + "first_run/"
for filename in os.listdir(first_run_dir) :
    if(filename.split('-')[0] == 'maze_2019') :
        plot_map(first_run_dir + filename + "/bd_003999.log","intermediate pos","final_archive.pdf",0)
        plot_map(first_run_dir + filename + "/bd_003999.log","final pos","final_archive.pdf",3)
# Out:
# CONTROL EXPERIMENT no novelty no neat
# intermediate pos
# nb points: 400 min=(21.76, 476.26) max=(319.66,568.67)
# final_pos
# nb points: 400 min=(21.75, 474.75) max=(339.93,569.24)
# intermediate pos
# nb points: 400 min=(21.75, 474.87) max=(360.25,569.25)
# final_pos
# nb points: 400 min=(21.76, 474.87) max=(357.53,569.23)
# intermediate pos
# nb points: 400 min=(21.93, 477.75) max=(372.23,569.24)
# final_pos
# nb points: 400 min=(21.75, 474.81) max=(522.57,569.22)
# intermediate pos
# nb points: 400 min=(21.75, 475.98) max=(388.42,569.23)
# final_pos
# nb points: 400 min=(21.75, 474.76) max=(389.67,569.23)
# intermediate pos
# nb points: 400 min=(21.75, 475.12) max=(380.19,569.23)
# final_pos
# nb points: 400 min=(21.75, 354.78) max=(406.44,569.23)
# intermediate pos
# nb points: 400 min=(21.77, 474.79) max=(344.62,569.21)
# final_pos
# nb points: 400 min=(21.75, 474.84) max=(522.75,569.23)
# intermediate pos
# nb points: 400 min=(21.76, 474.75) max=(394.36,568.59)
# final_pos
# nb points: 400 min=(21.81, 270.80) max=(524.04,569.22)
# intermediate pos
# nb points: 400 min=(21.77, 437.62) max=(394.68,569.18)
# final_pos
# nb points: 400 min=(21.91, 421.60) max=(514.25,569.05)
# intermediate pos
# nb points: 400 min=(21.93, 475.17) max=(380.06,569.25)
# final_pos
# nb points: 400 min=(21.78, 233.28) max=(522.74,569.25)
# intermediate pos
# nb points: 400 min=(21.78, 475.18) max=(522.10,569.18)
# final_pos
# nb points: 400 min=(21.76, 475.18) max=(522.71,569.11)
# intermediate pos
# nb points: 400 min=(21.79, 474.78) max=(344.88,569.25)
# final_pos
# nb points: 400 min=(21.75, 475.06) max=(519.33,569.00)
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
print("First run: novelty + fixedNN")
first_run_dir = logs_dir + "first_run/"
for filename in os.listdir(first_run_dir) :
    if(filename.split('-')[0] == 'maze_novelty_2019') :
        plot_map(first_run_dir + filename + "/bd_003999.log","intermediate pos","final_archive.pdf",0)
        plot_map(first_run_dir + filename + "/bd_003999.log","final pos","final_archive.pdf",3)
# Out:
# First run: novelty + fixedNN
# nb points: 400 min=(23.67, 36.86) max=(545.19,564.75)
# nb points: 400 min=(25.24, 36.58) max=(545.25,567.75)
# nb points: 400 min=(23.57, 38.32) max=(545.19,569.05)
# nb points: 400 min=(23.26, 29.28) max=(545.17,569.19)
# nb points: 400 min=(23.25, 38.91) max=(541.77,568.96)
# nb points: 400 min=(23.26, 35.27) max=(543.73,569.24)
# nb points: 400 min=(23.26, 36.76) max=(545.19,567.74)
# nb points: 400 min=(22.39, 29.27) max=(545.25,569.24)
# nb points: 400 min=(27.22, 38.28) max=(545.20,567.78)
# nb points: 400 min=(21.76, 29.27) max=(545.04,569.05)
# nb points: 400 min=(23.35, 38.29) max=(545.16,569.25)
# nb points: 400 min=(23.30, 31.52) max=(545.23,567.65)
# nb points: 400 min=(23.29, 35.26) max=(543.55,569.23)
# nb points: 400 min=(21.75, 29.38) max=(545.21,567.80)
# nb points: 400 min=(23.35, 38.32) max=(544.99,569.16)
# nb points: 400 min=(23.26, 29.69) max=(545.24,569.04)
# nb points: 400 min=(24.78, 35.84) max=(545.19,569.17)
# nb points: 400 min=(23.25, 30.20) max=(543.74,569.24)
# nb points: 400 min=(23.25, 38.32) max=(544.10,567.75)
# nb points: 400 min=(21.96, 29.34) max=(545.17,566.25)
# nb points: 400 min=(23.32, 35.43) max=(544.88,569.25)
# nb points: 400 min=(24.79, 33.08) max=(545.16,566.79)
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
print("First run : neat + novelty")
first_run_dir = logs_dir + "first_run/"
for filename in os.listdir(first_run_dir) :
    if(filename.split('-')[0] == 'maze_novelty_neat_2019') :
        plot_map(first_run_dir + filename + "/bd_003999.log","intermediate pos","final_archive.pdf",0)
        plot_map(first_run_dir + filename + "/bd_003999.log","final pos","final_archive.pdf",3)
# Out:
# First run : neat + novelty
# nb points: 400 min=(21.77, 31.83) max=(544.88,567.75)
# nb points: 400 min=(21.95, 29.83) max=(545.21,567.75)
# nb points: 400 min=(23.27, 35.26) max=(544.76,569.22)
# nb points: 400 min=(21.95, 33.56) max=(545.21,569.11)
# nb points: 400 min=(21.98, 38.27) max=(545.23,569.25)
# nb points: 400 min=(24.10, 29.27) max=(544.96,569.16)
# nb points: 400 min=(23.30, 38.33) max=(543.59,566.20)
# nb points: 400 min=(23.30, 31.00) max=(545.25,567.88)
# nb points: 400 min=(23.25, 38.33) max=(543.73,567.75)
# nb points: 400 min=(21.80, 29.26) max=(544.39,568.09)
# nb points: 400 min=(23.30, 30.79) max=(544.94,569.23)
# nb points: 400 min=(23.26, 30.22) max=(544.48,569.13)
# nb points: 400 min=(21.83, 38.27) max=(544.47,568.71)
# nb points: 400 min=(23.17, 30.79) max=(544.86,569.24)
# nb points: 400 min=(22.15, 32.22) max=(545.09,568.74)
# nb points: 400 min=(23.26, 32.28) max=(544.08,569.00)
# nb points: 400 min=(23.26, 38.25) max=(544.02,568.92)
# nb points: 400 min=(21.87, 31.01) max=(545.20,567.74)
# nb points: 400 min=(23.93, 38.32) max=(544.66,568.30)
# nb points: 400 min=(23.87, 31.25) max=(544.04,569.24)
# nb points: 400 min=(21.80, 35.28) max=(545.10,566.10)
# nb points: 400 min=(21.81, 30.82) max=(545.25,569.21)
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
print("Second run : \"long run\" with 10000 gen and 400 init population" )
print("Control exp : no novelty no neat")
second_run_dir = logs_dir + "long_run/"
for filename in os.listdir(second_run_dir) :
    if(filename.split('-')[0] == 'maze_2019') :
        plot_map(second_run_dir + filename + "/bd_010000.log","intermediate pos","final_archive.pdf",0)
        plot_map(second_run_dir + filename + "/bd_010000.log","final pos","final_archive.pdf",3)
# Out:
# Second run : "long run" with 10000 gen and 400 init population
# Control exp : no novelty no neat
# nb points: 400 min=(21.79, 474.80) max=(522.30,569.23)
# nb points: 400 min=(21.99, 251.26) max=(464.85,569.23)
# nb points: 400 min=(21.75, 475.26) max=(383.07,569.24)
# nb points: 400 min=(21.75, 475.26) max=(383.07,569.24)
# nb points: 400 min=(21.78, 474.75) max=(396.93,569.20)
# nb points: 400 min=(21.86, 474.75) max=(394.86,569.25)
# nb points: 400 min=(21.76, 475.48) max=(521.98,569.23)
# nb points: 400 min=(21.75, 230.53) max=(535.98,569.20)
# nb points: 400 min=(21.89, 474.78) max=(364.78,569.23)
# nb points: 400 min=(21.75, 474.78) max=(364.78,569.24)
# nb points: 400 min=(21.97, 477.26) max=(417.12,569.04)
# nb points: 400 min=(21.75, 474.75) max=(426.75,569.25)
# nb points: 400 min=(21.75, 476.32) max=(366.68,569.18)
# nb points: 400 min=(21.75, 474.83) max=(366.68,569.24)
# nb points: 400 min=(21.75, 417.79) max=(519.49,569.19)
# nb points: 400 min=(21.75, 333.41) max=(511.27,569.19)
# nb points: 400 min=(21.75, 475.65) max=(359.80,569.24)
# nb points: 400 min=(21.77, 384.58) max=(356.01,569.15)
# nb points: 400 min=(21.75, 214.51) max=(537.74,569.00)
# nb points: 400 min=(21.75, 372.92) max=(410.09,569.23)

# %%
print("second_run : novelty + fixed NN")
second_run_dir = logs_dir + "long_run/"
for filename in os.listdir(second_run_dir) :
    if(filename.split('-')[0] == 'maze_novelty_2019') :
        plot_map(second_run_dir + filename + "/bd_010000.log","intermediate pos","final_archive.pdf",0)
        plot_map(second_run_dir + filename + "/bd_010000.log","final pos","final_archive.pdf",3)
# Out:
# second_run : novelty + fixed NN
# nb points: 400 min=(23.25, 38.63) max=(545.15,569.24)
# nb points: 400 min=(22.61, 35.57) max=(545.15,569.24)
# nb points: 400 min=(23.27, 39.57) max=(544.71,569.25)
# nb points: 400 min=(23.43, 35.51) max=(545.23,568.92)
# nb points: 400 min=(21.75, 38.26) max=(544.81,569.25)
# nb points: 400 min=(22.35, 35.80) max=(545.22,568.97)
# nb points: 400 min=(23.26, 38.39) max=(545.16,569.25)
# nb points: 400 min=(23.26, 31.24) max=(544.93,569.24)
# nb points: 400 min=(23.27, 38.33) max=(542.11,566.83)
# nb points: 400 min=(23.28, 29.33) max=(545.24,569.17)
# nb points: 400 min=(23.69, 39.84) max=(541.44,569.25)
# nb points: 400 min=(23.28, 36.12) max=(545.11,569.15)
# nb points: 400 min=(23.28, 41.42) max=(545.13,569.25)
# nb points: 400 min=(22.62, 38.86) max=(544.69,569.23)
# nb points: 400 min=(23.25, 35.27) max=(543.07,569.18)
# nb points: 400 min=(21.75, 35.72) max=(542.50,569.19)
# nb points: 400 min=(23.26, 38.46) max=(543.50,568.66)
# nb points: 400 min=(23.25, 35.30) max=(545.01,569.25)
# nb points: 400 min=(27.93, 35.33) max=(544.59,568.90)
# nb points: 400 min=(23.30, 35.84) max=(543.66,567.71)

# %%
print("second_run : novelty + neat")
second_run_dir = logs_dir + "long_run/"
for filename in os.listdir(second_run_dir) :
    if(filename.split('-')[0] == 'maze_novelty_neat_2019') :
        plot_map(second_run_dir + filename + "/bd_010000.log","intermediate pos","final_archive.pdf",0)
        plot_map(second_run_dir + filename + "/bd_010000.log","final pos","final_archive.pdf",3)
# Out:
# second_run : novelty + neat
# nb points: 400 min=(24.70, 35.93) max=(545.21,568.91)
# nb points: 400 min=(23.49, 30.82) max=(544.72,567.74)
# nb points: 400 min=(23.31, 32.56) max=(545.18,569.20)
# nb points: 400 min=(23.26, 30.76) max=(544.76,569.22)
# nb points: 400 min=(23.48, 30.80) max=(545.18,569.09)
# nb points: 400 min=(23.29, 30.08) max=(545.24,568.95)
# nb points: 400 min=(22.48, 30.76) max=(544.87,568.05)
# nb points: 400 min=(22.29, 29.28) max=(544.09,568.35)
# nb points: 400 min=(23.27, 35.28) max=(545.14,569.22)
# nb points: 400 min=(23.32, 29.55) max=(543.75,568.81)
# nb points: 400 min=(23.26, 36.05) max=(544.58,567.74)
# nb points: 400 min=(21.91, 32.25) max=(545.15,569.12)
# nb points: 400 min=(21.77, 32.91) max=(545.25,568.22)
# nb points: 400 min=(21.99, 29.27) max=(543.65,569.06)
# nb points: 400 min=(23.26, 33.77) max=(543.13,569.04)
# nb points: 400 min=(23.26, 30.46) max=(541.24,568.85)
# nb points: 400 min=(22.59, 36.11) max=(543.48,569.17)
# nb points: 400 min=(21.79, 31.77) max=(544.89,568.95)
# nb points: 400 min=(23.31, 31.07) max=(543.63,569.25)
# nb points: 400 min=(23.28, 35.25) max=(543.59,567.40)
